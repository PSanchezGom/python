# %% [markdown]
# **Modulos o Librerias:** funciones que han escrito otros. Pueden usarse gratuitamente, o crear nuevos y compartirlos.

# %%
#"os": permite navegar como si estuviera dentro de consola de comandos
import os

# %%
#Ubicacion dentro de la carpeta
os.getcwd()
# Out:
# '/content'

# %%
#Ver contenido
os.listdir()
# Out:
# ['.config',
#  'StudentsPerformance (1) - StudentsPerformance (1).csv',
#  'nueva carpeta',
#  'sample_data']

# %%
#Crear nueva carpeta
os.makedirs("nueva carpeta")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-31-adb3b66ff8a6> in <cell line: 2>()
#       1 #Crear nueva carpeta
# ----> 2 os.makedirs("nueva carpeta")
#
# /usr/lib/python3.10/os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: 'nueva carpeta'

# %%
os.listdir()

# %% [markdown]
# Se activarán 2 bibliotecas (numpy y pandas). Para crear ddataframe, se usa metodo de lectura directa desde archivo.

# %%
import pandas as pd
import numpy as np

# %%
#Crear dataframe: Metodo "array"
dataframe_1=np.array([[2,4],[3,5],[6,8],[11,12]])

# %%
#Para crear dataframe se debe usar pandas
pd.DataFrame(dataframe_1)

# %%
dataframe_2=np.array([[0,5,10],[15,20,25],[30,35,40],[45,50,55]])

# %%
pd.DataFrame(dataframe_2)

# %%
#cambiar nombrea a columnas
df2=pd.DataFrame(dataframe_2,index=['fila 1','fila2','fila 3','fila 4'],
                 columns=['C1','C2','C3'])

# %%
df2
# Out:
#         C1  C2  C3
# fila 1   0   5  10
# fila2   15  20  25
# fila 3  30  35  40
# fila 4  45  50  55

# %%
dataframe_3=[[2,3],[4,6],[7,8]]

# %%
df3=pd.DataFrame(dataframe_3,index=['F1','F2','F3'],
                 columns=['C1','C2'])

# %%
df3
# Out:
#     C1  C2
# F1   2   3
# F2   4   6
# F3   7   8

# %%
dataframe_4=[['Pedro','Sanchez',23],['Daniel','Cepeda',44],['Irma','Salazar',34]]

# %%
df4=pd.DataFrame(dataframe_4,index=[1,2,3],
                 columns=['Nombre','Apellido','Edad'])

# %%
df4
# Out:
#    Nombre Apellido  Edad
# 1   Pedro  Sanchez    23
# 2  Daniel   Cepeda    44
# 3    Irma  Salazar    34

# %% [markdown]
# 3er método, usa **diccionarios**

# %%
#Crea dos(o más) listas
ciudadColombia=['Cali','Bogota','Barranquilla','Medellin']
ciudadPoblacion=[2340000,11000000,1200000,2500000]

# %%
#Crear diccionarios con listas
ciudades={'ciudades':ciudadColombia, 'poblacion':ciudadPoblacion}

# %%
df5=pd.DataFrame(ciudades,index=['ciudad1','ciudad2','ciudad3','ciudad4'])

# %%
df5
# Out:
#              ciudades  poblacion
# ciudad1          Cali    2340000
# ciudad2        Bogota   11000000
# ciudad3  Barranquilla    1200000
# ciudad4      Medellin    2500000

# %% [markdown]
# **Paises** con *Poblacion* y *expectativa de vida*

# %%
paisesMundo=['Liechtenstein','Brasil','Singapur','Colombia']
paisesPoblacion=[40000,215000000,5900000,51000000]
paisesExVida=[85,76,84,77]

# %%
paises={'Pais':paisesMundo,'Poblacion':paisesPoblacion,'Expectativa de Vida (años)':paisesExVida}
df6=pd.DataFrame(paises, index=['P1','P2','P3','P4'])
df6
# Out:
#              Pais  Poblacion  Expectativa de Vida (años)
# P1  Liechtenstein      40000                          85
# P2         Brasil  215000000                          76
# P3       Singapur    5900000                          84
# P4       Colombia   51000000                          77

# %% [markdown]
# **Opcion 4:** Asi se suben dataframes constantemente. Requiere menos codigo

# %%
#Método "read" de panda para leer archivo CSV
estudiantes=pd.read_csv('/content/StudentsPerformance (1) - StudentsPerformance (1).csv')

# %%
estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Mostrar 5 primeras columnas
estudiantes.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
estudiantes.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
estudiantes.head(15)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
estudiantes.shape
# Out:
# (1000, 8)

# %%
#Para visualizar el número de filas que desee se usa "head"
estudiantes.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
estudiantes.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
estudiantes.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#Ver tipo de dato de las columnas
estudiantes.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#Obtener informacion de todo el dataframe
estudiantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
estudiantes.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
len(estudiantes)
# Out:
# 1000

# %%
max(estudiantes.index)
# Out:
# 999

# %%
type(estudiantes)
# Out:
# pandas.core.frame.DataFrame

# %%
round(estudiantes)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#mostrar solo 1 columna
estudiantes['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
estudiantes['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
estudiantes['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
estudiantes['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
#Usando nombre como metodo - NO ES BUENA PRACTICA
estudiantes.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
estudiantes['parental level of education']
# Out:
# 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: object

# %%
estudiantes[['race/ethnicity','parental level of education']].head(60)
# Out:
#    race/ethnicity parental level of education
# 0         group B           bachelor's degree
# 1         group C                some college
# 2         group B             master's degree
# 3         group A          associate's degree
# 4         group C                some college
# 5         group B          associate's degree
# 6         group B                some college
# 7         group B                some college
# 8         group D                 high school
# 9         group B                 high school
# 10        group C          associate's degree
# 11        group D          associate's degree
# 12        group B                 high school
# 13        group A                some college
# 14        group A             master's degree
# 15        group C            some high school
# 16        group C                 high school
# 17        group B            some high school
# 18        group C             master's degree
# ...

# %%
#Agrupar por columna
df_estudiantes=estudiantes.groupby('parental level of education').value_counts(normalize=True)*100
df_estudiantes
# Out:
# parental level of education  gender  race/ethnicity  lunch         test preparation course  math score  reading score  writing score
# associate's degree           female  group A         free/reduced  none                     37          57             56               0.450450
#                                                                                             41          51             48               0.450450
#                                                                                             65          85             76               0.450450
#                                                      standard      completed                55          65             62               0.450450
#                                                                                             65          70             74               0.450450
# ...

# %%
#Ordenar por valor de matematicas en ascendentes
estudiantes.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_estudiantes=estudiantes.sort_values('math score')

# %%
#PARA DESCARGAR DATOS
df_estudiantes.to_csv('df_estudiantes.csv',index=False)

# %%
#Organizar datos de manera descendente
df_estudiantes.sort_values('math score',ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 962  female        group E          associate's degree      standard
# 451  female        group E                some college      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Ordenar dataframe por varias columnas. Primer dato es principal, segundo dependiente.
df_estudiantes.sort_values(['reading score','writing score'],ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 970  female        group D           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
organizado_lectura=df_estudiantes.sort_values(['reading score','writing score'],ascending=False)
organizado_lectura.to_csv('organizado_lectura.csv',index=False)

# %%
#Guardar datos y sobreescribir sin usar la variable: método "inplace"
df_estudiantes.sort_values(['reading score','writing score'],ascending=False,
                           inplace=True)

# %%
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 970  female        group D           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Organizar valores por texto: funcion "lambda"
#Convierte valores en minuscula y ordena
df_estudiantes.sort_values('race/ethnicity',ascending=True,
                           key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 837  female        group A                 high school      standard
# 129  female        group A           bachelor's degree      standard
# 467    male        group A                 high school  free/reduced
# 511    male        group A            some high school      standard
# 378  female        group A            some high school      standard
# ..      ...            ...                         ...           ...
# 186    male        group E                 high school      standard
# 968  female        group E          associate's degree      standard
# 269  female        group E                some college  free/reduced
# 926    male        group E          associate's degree  free/reduced
# 881  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...
